# %%
import pandas as pd
import fairtl as fl

# %%
df = pd.read_excel('/mnt/c/Users/Morning/Desktop/dataset_122/U16.xlsx')

# %%
df.head(10)
# Out:
#    id  gender      PPE      DFA     RPDE  numPulses  numPeriodsPulses  \
# 0   0       1  0.85247  0.71826  0.57227        240               239
# 1   0       1  0.76686  0.69481  0.53966        234               233
# 2   0       1  0.85083  0.67604  0.58982        232               231
# 3   1       0  0.41121  0.79672  0.59257        178               177
# 4   1       0  0.32790  0.79782  0.53028        236               235
# 5   1       0  0.50780  0.78744  0.65451        226               221
# 6   2       1  0.76095  0.62145  0.54543        322               321
# 7   2       1  0.83671  0.62079  0.51179        318               317
# 8   2       1  0.80826  0.61766  0.50447        318               317
# 9   3       0  0.85302  0.62247  0.54855        493               492
#
#    meanPeriodPulses  stdDevPeriodPulses  locPctJitter  ...  \
# 0          0.008064            0.000087       0.00218  ...
# 1          0.008258            0.000073       0.00195  ...
# ...

# %%
df['class'].unique()
# Out:
# array([1, 0])

# %%
df['gender'].unique()
# Out:
# array([1, 0])

# %%
female = fl.EMD(df, 'gender', 'class', 0, 1000)
print(female)
# Out:
# (0.08209731980223783, 0.006, array([[0.25396825, 0.08209732],
#        [0.        , 0.66393443]]))

# %%
male = fl.EMD(df, 'gender', 'class', 1, 1000)
print(male)
# Out:
# (0.077045177045177, 0.002, array([[0.74603175, 0.07704518],
#        [0.        , 0.17692308]]))

# %%
df.shape
# Out:
# (756, 755)
