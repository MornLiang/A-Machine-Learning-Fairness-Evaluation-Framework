# %%
import pandas as pd
import fairtl as fl
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
df = pd.read_csv('/mnt/c/Users/Morning/Desktop/MORNING_NEXT/parkinson+s+disease+classification/pd_speech_features/pd_speech_features.csv')

# %%
df.head(10)
# Out:
#    id  gender      PPE      DFA     RPDE  numPulses  numPeriodsPulses  \
# 0   0       1  0.85247  0.71826  0.57227        240               239
# 1   0       1  0.76686  0.69481  0.53966        234               233
# 2   0       1  0.85083  0.67604  0.58982        232               231
# 3   1       0  0.41121  0.79672  0.59257        178               177
# 4   1       0  0.32790  0.79782  0.53028        236               235
# 5   1       0  0.50780  0.78744  0.65451        226               221
# 6   2       1  0.76095  0.62145  0.54543        322               321
# 7   2       1  0.83671  0.62079  0.51179        318               317
# 8   2       1  0.80826  0.61766  0.50447        318               317
# 9   3       0  0.85302  0.62247  0.54855        493               492
#
#    meanPeriodPulses  stdDevPeriodPulses  locPctJitter  ...  \
# 0          0.008064            0.000087       0.00218  ...
# 1          0.008258            0.000073       0.00195  ...
# ...

# %%
df.shape
# Out:
# (756, 755)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Columns: 755 entries, id to class
# dtypes: float64(749), int64(6)
# memory usage: 4.4 MB

# %%
df.isna().sum().sum()
# Out:
# np.int64(0)

# %%
df['gender'].unique()
# Out:
# array([1, 0])

# %%
y = df['class'].values
X = df.drop('class', axis=1)

# %%
print(X.shape)
selector = VarianceThreshold(threshold=0.1)
X = selector.fit_transform(X)
print(X.shape)
# Out:
# (756, 754)
# (756, 340)

# %%
# build mask
gender_0_mask = df['gender'] == 0
gender_1_mask = df['gender'] == 1

count_gender_0 = gender_0_mask.sum()
count_gender_1 = gender_1_mask.sum()

print("Female: ", count_gender_0)
print("Male: ", count_gender_1)

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_scaled_Gender_0 = X_scaled[gender_0_mask]
X_scaled_Gender_1 = X_scaled[gender_1_mask]
y_Gender_0 = y[gender_0_mask]
y_Gender_1 = y[gender_1_mask]
# Out:
# Female:  366
# Male:  390

# %%
seed = 42
models = fl.build_models(seed)

results_list = []

kf = KFold(n_splits=5, shuffle=True, random_state=seed)

# %%
print("Starting experiments for Female(0)")
fl.run_experiment(kf, models, X_scaled_Gender_0, y_Gender_0, 'Female', results_list)

print("Starting experiments for Male(1)")
fl.run_experiment(kf, models, X_scaled_Gender_1, y_Gender_1, 'Male', results_list)

final_results_df = pd.concat(results_list, ignore_index=True)
print(final_results_df)
# Out:
# Starting experiments for Female(0)
# Processing fold 1 for group Female
# Training and evaluating model: SVM
# Training and evaluating model: LR
# Training and evaluating model: KNN
# Training and evaluating model: RF
# Training and evaluating model: DT
# Training and evaluating model: ANN
# Training and evaluating model: NB
# Processing fold 2 for group Female
# Training and evaluating model: SVM
# Training and evaluating model: LR
# Training and evaluating model: KNN
# Training and evaluating model: RF
# Training and evaluating model: DT
# Training and evaluating model: ANN
# Training and evaluating model: NB
# Processing fold 3 for group Female
# Training and evaluating model: SVM
# Training and evaluating model: LR
# Training and evaluating model: KNN
# Training and evaluating model: RF
# Training and evaluating model: DT
# Training and evaluating model: ANN
# Training and evaluating model: NB
# Processing fold 4 for group Female
# Training and evaluating model: SVM
# ...

# %%
results_df = pd.concat(results_list, ignore_index=True)

# %%
result_path = './results/u16_result.xlsx'
results_df.to_excel(result_path, index=False)

# %%
df = pd.read_excel(result_path)
df.head()
# Out:
#    Fold   Group   SVM_TPR   SVM_TNR   SVM_FPR   SVM_FNR  SVM_TP  SVM_TN  \
# 0     1  Female  0.913043  0.607143  0.392857  0.086957      42      17
# 1     2  Female  0.980392  0.681818  0.318182  0.019608      50      15
# 2     3  Female  0.938776  0.500000  0.500000  0.061224      46      12
# 3     4  Female  0.958333  0.520000  0.480000  0.041667      46      13
# 4     5  Female  0.959184  0.708333  0.291667  0.040816      47      17
#
#    SVM_FP  SVM_FN  ...  ANN_FP  ANN_FN    NB_TPR    NB_TNR    NB_FPR  \
# 0      11       4  ...       5       3  0.543478  0.857143  0.142857
# 1       7       1  ...       4       4  0.450980  0.954545  0.045455
# 2      12       3  ...       4       3  0.591837  0.625000  0.375000
# 3      12       2  ...       4       4  0.562500  0.800000  0.200000
# 4       7       2  ...       6       3  0.571429  0.875000  0.125000
#
#      NB_FNR  NB_TP  NB_TN  NB_FP  NB_FN
# 0  0.456522     25     24      4     21
# ...

# %%
label = 'Female'

fl.perform_t_tests(df, 'SVM', label)
fl.perform_t_tests(df, 'DT', label)
fl.perform_t_tests(df, 'RF', label)
fl.perform_t_tests(df, 'LR', label)
fl.perform_t_tests(df, 'KNN', label)
fl.perform_t_tests(df, 'ANN', label)
fl.perform_t_tests(df, 'NB', label)
# Out:
# SVM -TPR: MannwhitneyuResult(statistic=np.float64(0.0), pvalue=np.float64(0.007494957516935239))
# SVM - FPR: TtestResult(statistic=np.float64(-10.078583269082642), pvalue=np.float64(8.0061007625963e-06), df=np.float64(8.0))
# SVM - FN/FP: MannwhitneyuResult(statistic=np.float64(25.0), pvalue=np.float64(0.007494957516935239))
# DT -TPR: TtestResult(statistic=np.float64(-1.4809122085403232), pvalue=np.float64(0.17690405470232157), df=np.float64(8.0))
# DT - FPR: TtestResult(statistic=np.float64(-0.5029999694813726), pvalue=np.float64(0.6285175877470416), df=np.float64(8.0))
# DT - FN/FP: TtestResult(statistic=np.float64(-2.0098409035581866), pvalue=np.float64(0.07929774171354113), df=np.float64(8.0))
# RF -TPR: MannwhitneyuResult(statistic=np.float64(0.0), pvalue=np.float64(0.009700785068229596))
# RF - FPR: TtestResult(statistic=np.float64(-8.955288299929721), pvalue=np.float64(1.922198468685586e-05), df=np.float64(8.0))
# ...
